# %% [markdown]
# # Job Title Normalizer

# %%
import re
job_title = input("Enter Job title to normalize:")
clean_txt = re.sub(r"[^A-Za-z ]","",job_title)
print(clean_txt)
# Out:
# Enter Job title to normalize: Full Stack & Web Devel9oper
# Full Stack  Web Developer
