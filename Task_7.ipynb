# %% [markdown]
# # Simple Email Extractor

# %%
input_text = input("Enter a text to check email or not:")
input_as_list = input_text.split()
email = ""
for word in input_as_list:
    if '@' in word:
        email = word
        break
if email:
    print("Email Extracted :",email)
else:
    print("No email detected")
# Out:
# Enter a text to check email or not: My email id is abc6@gmail.com
# Email Extracted : abc6@gmail.com
