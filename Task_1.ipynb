# %% [markdown]
# # Basic Skill Matcher

# %%
resume_skills = "Python, Java, HTML, CSS"
resume_skills_list = resume_skills.split(", ")
job_description = ["Python", "PowerBI", "MySQL"]
Matched_skills = []
Missing_skills = []
for skill in job_description:
    if skill in resume_skills:
        Matched_skills.append(skill)
    else:
        Missing_skills.append(skill)
print(Matched_skills)
print(Missing_skills)
# Out:
# ['Python']
# ['PowerBI', 'MySQL']
