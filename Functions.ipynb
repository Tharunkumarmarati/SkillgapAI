# %% [markdown]
# # Python Function Practice Questions (10)

# %%
# 1. Write a function welcome() that prints 'Welcome to Python!'.
def welcome():
    return 'Welcome to Python!'
print("1. ",welcome())

# 2. Write a function greet(name) that prints 'Hello '.
name = "Tharun"
def greet(name):
    return "Hello "+name
print("2. ",greet(name))

# 3. Write a function square(n) that returns the square of n.
n = 10
def square(n):
    return n ** 2
print("3. ",square(n))

# 4. Write a function calculator(a, b) that returns the sum, difference, and product of a & b.
a,b = 5,4
def calculator(a, b):
    print("4. sum:",a + b)
    print("  Difference:",a - b)
    print("  Product:",a * b)
calculator(a,b)

# 5. Write a function country(name='India') that prints 'I am from '.
def country(name = 'India'):
    return "I am from "+name
print("5. ",country())

# 6. Write a function total(*nums) that returns the sum of all numbers passed.
def total(*nums):
    return sum(nums)
print("6. ",total(5,6,7))

# 7. Write a function student_info(**data) that prints key : value for all items.
def student_info(**data):
#    for key,value in data.items():
#        print(key,":",value)        - writes key and value pair line by line
    print("7. ",data)
student_info(name = "Tharun", age = 23, roll_no = 564)

# 8. Write a function count_vowels(text) that returns the number of vowels in the string.
text = "Infosys Springboard"
def count_vowels(text):
    count = 0
    for i in text:
        if i.lower() in 'a,e,i,o,u':
            count += 1
    print("8. count of vowels in a text :",count)
count_vowels(text)

# 9. Write a lambda function to return the cube of a number.
num = 9
cube = lambda x: x ** 3
print(f"9. cube of {num} is {cube(num)}")

# 10. Write a function unique_letters(text) that returns unique letters in the order they appear.
text = "daabbaca"
def unique_letters(text):
    unique = []
    for i in text:
        if i in unique:
            pass
        else:
            unique.append(i)
    print("10. unique letters",unique)
unique_letters(text)
# Out:
# 1.  Welcome to Python!
# 2.  Hello Tharun
# 3.  100
# 4. sum: 9
#   Difference: 1
#   Product: 20
# 5.  I am from India
# 6.  18
# 7.  {'name': 'Tharun', 'age': 23, 'roll_no': 564}
# 8. count of vowels in a text : 5
# 9. cube of 9 is 729
# 10. unique letters ['d', 'a', 'b', 'c']
