# %% [markdown]
# # Module Practice Questions (20)

# %%
#1. Use math.sqrt() to find the square root of a number.
import math
num = 25
print("1. ",math.sqrt(num))

#2. Use math.floor() and math.ceil() to round 5.67.
print("2. ",math.floor(5.67))
print("   ",math.ceil(5.67))

#3. Generate a random number between 1 and 100.
import random
print("3. ",random.randint(1,100))

#4. Print 5 random integers between 10 and 20.
print("4. ",end = "")
for i in range(5):
    print("  ",random.randint(10,20))

#5. Print today’s date using datetime.date.today().
import datetime
print("5. ",datetime.date.today())

#6. Print the current year, month, and day separately.
print("6. Year:",datetime.date.today().year)
print("   Month:",datetime.date.today().month)
print("   Day:",datetime.date.today().day)

#7. Print the current working directory using os.getcwd().
import os
print("7. ", os.getcwd())

#8. List all files in the current directory using os.listdir().
print("8. ",os.listdir())

#9. Print the current Python version using sys.version.
import sys
print("9. ",sys.version)

#10. Convert a JSON string to a dictionary using json.loads().
import json
json_string = '{"Name":"Tharun","Age":23}'
print("10. ",json.loads(json_string))

#11. Use math functions to compute cos(0), sin(90°), and log(10).
print("11. ", math.cos(0))
print("    ", math.sin(90))
print("    ", math.log(10))
#12. Simulate rolling a dice 10 times and store the results.
results = []
for i in range(10):
    rolls = random.randint(1,6)
    results.append(rolls)
print("12. ",results)
#13. Print how many days are left for your next birthday.

from datetime import datetime
birthday_day = 28
birthday_month = 2
today = datetime.today()
current_year = today.year
next_birthday = datetime(current_year, birthday_month, birthday_day)
if next_birthday < today:
    next_birthday = datetime(current_year + 1, birthday_month, birthday_day)
days_left = (next_birthday - today).days
print("13. Days left for your next birthday:", days_left)

#14. Convert the date '2022-05-15' to a datetime object and add 30 days.
from datetime import datetime, timedelta
date_str = '2022-05-15'
date_obj = datetime.strptime(date_str, '%Y-%m-%d')
new_date = date_obj + timedelta(days=30)
print("14. Original date:", date_obj)
print("    Date after adding 30 days:", new_date)


#15. Create a new folder named 'backup' using os.mkdir().
print("15. ",os.mkdir("D:/backup"))


#16. Convert a dictionary to JSON using json.dumps().
dictionary = {"Name":"Tharun","age":23}
print("16. ",json.dumps(dictionary))

#17. Use regex to extract all digits from a string.
import re
string = "AB1C3D2"
print("17. ",re.findall(r"\d",string))

#18. Check if a string starts with 'Hello' using regex.
text = "Hello Python"
pattern = "^Hello"
if re.match(pattern,text):
    print("18. ",text,"starts with Hello")
else:
    print("18. ",text,"not starts with Hello")
    
#19. Find mean, median, and mode using the statistics module.
import statistics as s
lis = [1,2,7,4,5,7,3,6]
print("19. Mean:",s.mean(lis))
print("    Median:",s.median(lis))
print("    Mode: ",s.mode(lis))

#20. Measure execution time of a loop from 1 to 1,000,000 using time module.
import time
start = time.time()
for i in range(1,1000001):
    pass
end = time.time()
print("20. Execution Time:",start-end,"seconds")
# Out:
# 1.  5.0
# 2.  5
#     6
# 3.  57
# 4.    11
#    17
#    15
#    16
#    13
# 5.  2025-12-10
# 6. Year: 2025
#    Month: 12
#    Day: 10
# 7.  C:\Users\tarun\Infosys_Springboard
# 8.  ['.ipynb_checkpoints', 'Functions.ipynb', 'Loops.ipynb', 'Modules.ipynb', 'Operators.ipynb', 'String_Section_1.ipynb', 'String_section_2.ipynb']
# 9.  3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, 16:37:03) [MSC v.1929 64 bit (AMD64)]
# 10.  {'Name': 'Tharun', 'Age': 23}
# 11.  1.0
#      0.8939966636005579
#      2.302585092994046
# 12.  [5, 5, 3, 4, 4, 5, 1, 1, 4, 3]
# 13. Days left for your next birthday: 79
# 14. Original date: 2022-05-15 00:00:00
#     Date after adding 30 days: 2022-06-14 00:00:00
# 15.  None
# 16.  {"Name": "Tharun", "age": 23}
# 17.  ['1', '3', '2']
# 18.  Hello Python starts with Hello
# 19. Mean: 4.375
#     Median: 4.5
#     Mode:  7
# 20. Execution Time: -0.11627912521362305 seconds
